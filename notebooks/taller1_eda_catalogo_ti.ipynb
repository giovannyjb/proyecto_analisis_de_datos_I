# %% [markdown]
# # Taller 1 — Catálogo de Servicios TI
#
# **Grupo 3**
#
# ---
#
# **Este notebook es solo un esqueleto.** No contiene análisis ni resultados. Aquí iremos trabajando cuando el equipo tenga:
#
# - las respuestas cerradas a las preguntas del taller
# - los datos descargados en `data/raw/`
#
# Documentación del equipo: ver carpeta [`docs/taller1/`](../docs/taller1/).

# %% [markdown]
# ---
# ## Sección A — Definición del problema
#
# _Completar en equipo. También en `docs/taller1/definicion_problema.md`._
#
# - Descripción del problema:
# - KPI / métrica:
# - Tipo de analítica:
# - Caso similar:
# - Tipo de problema de IA:
# - Datos necesarios:
# - Impacto en el negocio:

# %% [markdown]
# ---
# ## Sección B — Pregunta SMART
#
# _Completar en equipo. También en `docs/taller1/pregunta_smart.md`._
#
# **Pregunta:** _(pendiente)_
#
# - Específica:
# - Medible:
# - Accionable:
# - Realista:
# - Temporal:

# %% [markdown]
# ---
# ## Sección C — Datos
#
# - Drive: [Grupo 3](https://drive.google.com/drive/u/1/folders/1NzXBrdwk3EW74dB6GLmYZ_qp86arPvtH)
# - Carpeta local: `data/raw/` _(vacía por ahora)_
# - Diccionario: `docs/datos/fuentes_y_diccionario.md` _(pendiente)_
#
# Archivos que vamos a usar:
#
# | Archivo | ¿Qué contiene? | Estado |
# |---------|----------------|--------|
# | | | Pendiente |

# %% [markdown]
# ---
# ## Sección D — EDA (pendiente)
#
# Cuando tengamos datos y pregunta SMART, desarrollar aquí:
#
# 1. Carga de datos
# 2. Perfilado (dimensiones, nulos, tipos)
# 3. Exploración según la pregunta SMART
# 4. Visualizaciones
# 5. Conclusiones
#
# Utilidades del repo (para usar más adelante): `src/config.py`, `src/load_data.py`.

# %% [markdown]
# ---
# ## Sección E — Evidencia de IA generativa (pendiente)
#
# - Herramienta usada:
# - Qué partes se hicieron con IA:
# - Qué revisó el equipo:
